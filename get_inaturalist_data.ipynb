# %%
#basic package
import json
import tqdm
import os
import numpy as np
import glob
import pandas as pd
import sys
import shutil
import time
from PIL import Image
import pickle
import collections
from collections import Counter

#url open to get image
import urllib.request
from urllib.request import urlopen

#get data in parallel
from multiprocessing import Pool

#plot (for image verification)
import matplotlib.cm as cm
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# Root directory of the project
ROOT_DIR = os.path.abspath("../")
path_data = os.path.join(ROOT_DIR,'datasets/inaturalist')

# %%
PACKAGE_PARENT = '../../..'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser('__file__'))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))

from UTILS.utils import get_image
# Out:
# /home/camille/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Note this notebook can not be run in the same time as get_flickr_data on my computer, but it could on the cluster.
#Hence, depending on your computer you might or not be able to run both in the same time, but if you try verify its 
#blocked

# %% [markdown]
# # Download data

# %% [markdown]
# ### list of species and its synonymes

# %%
#dowload dictionary with keys=species, value=list of its synonyms
dico_syn = pickle.load(open(os.path.join(ROOT_DIR,'datasets','synonyms','dico_species_lisyn.pkl'), 'rb'))

# %% [markdown]
# #### create list of species and their synonymes

# %%
li_species_word = []
for k,v in dico_syn.items():
    li_species_word.append(k)
    li_species_word.extend(v)
print('There is %d species-word in total to query for'%len(li_species_word))
# Out:
# There is 18289 species-word in total to query for

# %%
#dico ith keys a species word and value its associated species name
dico_speciesword_species = {}
for k,v in dico_syn.items():
    for i in v+[k]:
            dico_speciesword_species[i] = k

# %% [markdown]
# ### inaturalist info

# %%
#to get url 
df_all= pd.read_csv(os.path.join(path_data, 'observations-39577.csv'), sep=',', parse_dates=['observed_on',
                                                                                          'time_observed_at'])
print(df_all.shape)
df_all.head(3)
# Out:
# (145481, 35)
#     id        observed_on_string observed_on    time_observed_at  \
# 0  122  September 10, 2007 12:00  2007-09-10 2007-09-10 19:00:00
# 1  369                   5/26/07  2007-05-26                 NaT
# 2  502                 07/12/08   2008-07-12                 NaT
#
#                     time_zone out_of_range  user_id    user_login  \
# 0  Pacific Time (US & Canada)          NaN       15       gdurkee
# 1  Eastern Time (US & Canada)          NaN       72  stellaoleary
# 2  Eastern Time (US & Canada)          NaN       19  justinscioli
#
#                   created_at                 updated_at    ...     \
# 0  2008-04-09 11:57:16 -0500  2017-07-31 03:48:31 -0500    ...
# 1  2008-06-05 14:04:53 -0500  2014-10-19 22:06:17 -0500    ...
# 2  2008-07-12 12:18:20 -0500  2015-11-07 00:16:04 -0600    ...
#
#   positional_accuracy geoprivacy coordinates_obscured positioning_method  \
# 0                 NaN        NaN                False                NaN
# 1                 NaN        NaN                False                NaN
# 2                 NaN        NaN                False                NaN
#
#   positioning_device          species_guess              scientific_name  \
# 0                NaN  Mountain Garter Snake   Thamnophis elegans elegans
# 1                NaN        black rat snake  Pantherophis alleghaniensis
# 2                NaN   Northern Water Snake      Nerodia sipedon sipedon
#
#              common_name  iconic_taxon_name  taxon_id
# 0  Mountain Garter Snake           Reptilia     28400
# 1      Eastern Rat Snake           Reptilia     59644
# 2   Northern Water Snake           Reptilia     29306
#
# [3 rows x 35 columns]

# %% [markdown]
# #### small preprocessing

# %%
df_all.rename(columns={'user_id':'photographer', 'url':'observation_url','scientific_name':'species_word'},inplace=True)
df_all.rename(columns={'image_url':'url'},inplace=True)

# %%
#make one good date
df_all['datetaken'] = np.where(df_all['time_observed_at'].isnull(), df_all['observed_on'],df_all['time_observed_at'])
#small verification
#df[['observed_on','time_observed_at','observed_on_string','datetaken']]

# %%
#potential new synonyms
dico_more_syn = dict(zip(df_all['species_word'], df_all['common_name']))
#verification: dico_more_syn['Malpolon monspessulanus']
#ask andrew if this might help (i..e secure thing from inaturalist of given by crowd)
pickle.dump(dico_more_syn, open(os.path.join(path_data,'dico_more_syn_common_name_inaturalist.pkl'), 'wb'))

# %%
#removing if not in our species-word list
df = df_all[df_all['species_word'].isin(li_species_word)]
print(df.shape)
#removing if no url
df = df[~df['url'].isnull()]
print(df.shape)
#add associated species name of the species word 
df['species'] = df['species_word'].map(lambda x: dico_speciesword_species[x])
df.head(3)
# Out:
# (113969, 36)
# (113967, 36)
#      id  observed_on_string observed_on    time_observed_at  \
# 1   369             5/26/07  2007-05-26                 NaT
# 5  1227  May 20, 2006 15:49  2006-05-20 2006-05-20 22:49:00
# 6  1228  May 13, 2006 19:36  2006-05-13 2006-05-14 02:36:00
#
#                     time_zone out_of_range  photographer    user_login  \
# 1  Eastern Time (US & Canada)          NaN            72  stellaoleary
# 5  Pacific Time (US & Canada)        False             1         kueda
# 6  Pacific Time (US & Canada)        False             1         kueda
#
#                   created_at                 updated_at  \
# 1  2008-06-05 14:04:53 -0500  2014-10-19 22:06:17 -0500
# 5  2009-01-13 02:29:54 -0600  2016-03-01 11:27:39 -0600
# 6  2009-01-13 02:29:54 -0600  2017-05-02 13:03:37 -0500
#
#               ...              coordinates_obscured positioning_method  \
# 1             ...                             False                NaN
# 5             ...                             False                NaN
# 6             ...                             False                NaN
#
#   positioning_device                                      species_guess  \
# 1                NaN                                    black rat snake
# 5                NaN  Western Terrestrial Garter Snake (Thamnophis e...
# 6                NaN                   Western Terrestrial Garter Snake
#
#                   species_word                       common_name  \
# 1  Pantherophis alleghaniensis                 Eastern Rat Snake
# 5           Thamnophis elegans  Western Terrestrial Garter Snake
# 6           Thamnophis elegans  Western Terrestrial Garter Snake
#
#   iconic_taxon_name  taxon_id           datetaken                      species
# 1          Reptilia     59644 2007-05-26 00:00:00  Pantherophis alleghaniensis
# 5          Reptilia     28398 2006-05-20 22:49:00           Thamnophis elegans
# 6          Reptilia     28398 2006-05-14 02:36:00           Thamnophis elegans
#
# [3 rows x 37 columns]

# %%
df['saved_img_id'] = df.apply(lambda x: 'inaturalist_'+x['species']+'_'+str(x['id'])+'.png', axis=1)
df['img_path'] = df.apply(lambda x: os.path.join(path_data, x['species'], x['saved_img_id']), axis=1)

# %%
li_species_flickr = list(set(df['species'].tolist()))
print('There is %d species-name with at least one image in Inaturalist'%len(li_species_flickr))
print('There is %d images to download from Inaturalist'%df.shape[0])
df.head(2)
# Out:
# There is 1591 species-name with at least one image in Inaturalist
# There is 113967 images to download from Inaturalist
#      id  observed_on_string observed_on    time_observed_at  \
# 1   369             5/26/07  2007-05-26                 NaT
# 5  1227  May 20, 2006 15:49  2006-05-20 2006-05-20 22:49:00
#
#                     time_zone out_of_range  photographer    user_login  \
# 1  Eastern Time (US & Canada)          NaN            72  stellaoleary
# 5  Pacific Time (US & Canada)        False             1         kueda
#
#                   created_at                 updated_at  \
# 1  2008-06-05 14:04:53 -0500  2014-10-19 22:06:17 -0500
# 5  2009-01-13 02:29:54 -0600  2016-03-01 11:27:39 -0600
#
#                          ...                         positioning_device  \
# 1                        ...                                        NaN
# 5                        ...                                        NaN
#
#                                        species_guess  \
# 1                                    black rat snake
# 5  Western Terrestrial Garter Snake (Thamnophis e...
#
#                   species_word                       common_name  \
# 1  Pantherophis alleghaniensis                 Eastern Rat Snake
# 5           Thamnophis elegans  Western Terrestrial Garter Snake
#
#   iconic_taxon_name taxon_id           datetaken                      species  \
# 1          Reptilia    59644 2007-05-26 00:00:00  Pantherophis alleghaniensis
# 5          Reptilia    28398 2006-05-20 22:49:00           Thamnophis elegans
#
#                                       saved_img_id  \
# 1  inaturalist_Pantherophis alleghaniensis_369.png
# 5          inaturalist_Thamnophis elegans_1227.png
#
#                                             img_path
# 1  /home/camille/vm_exchange/Lab/snakes/datasets/...
# 5  /home/camille/vm_exchange/Lab/snakes/datasets/...
#
# [2 rows x 39 columns]

# %%
if len(df['id'].tolist())!=len(set(df['id'].tolist())):
    print('ERROR: not unique ids of Inaturalist images')
    sys.exit()

# %% [markdown]
# # Download Inaturalist images

# %% [markdown]
# #in case to erase all (not csv data given by Andrew)
# for species in glob.glob(os.path.join(path_data,'*')):
#     if not species.endswith('.csv'):
#         shutil.rmtree(species)

# %%
#create appropriate folders if not existing
for species in li_species_flickr:
    folder_path_s = os.path.join(path_data,species)
    if not os.path.exists(folder_path_s):
        os.makedirs(folder_path_s)

# %%
def download_image(i):
    #download image and save it
    species = df.iloc[i]['species']
    f = os.path.join(path_data, species,'inaturalist_'+species+'_'+str(df.iloc[i]['id'])+".png")
    get_image(url=df.iloc[i]['url'], path=f, name=df.iloc[i]['species_word'])

# %%
#compute time needed to gather all images
start = time.time()
with Pool(50) as p:
    p.map(download_image, range(df.shape[0]))
end = time.time()
print ("Total running time: ", (end-start)/60) #in minutes
# Out:
# Not able to SAVE image for species Thamnophis hammondii and url http://sphotos-b.xx.fbcdn.net/hphotos-ash4/196550_4330579617765_564575578_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Crotalus armstrongi and url https://fbcdn-sphotos-g-a.akamaihd.net/hphotos-ak-xpa1/t1.0-9/p600x600/10625131_4626806324681_5460785350666786844_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Pituophis deppei and url https://scontent-b.xx.fbcdn.net/hphotos-xpa1/t1.0-9/p600x600/10417681_10203808709836444_675001840006000879_n.jpg, lets STOP due to:
#  HTTP Error 403: Access Denied
# Not able to SAVE image for species
n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Symphimus leucostomus and url https://scontent-b.xx.fbcdn.net/hphotos-ash4/q71/s720x720/1002778_10200883456761289_200318353_n.jpg, lets STOP due to:
#  HTTP Error 403: Access Denied
# Not able to SAVE image for species Storeria storerioides and url https://scontent-b.xx.fbcdn.net/hphotos-xap1/v/t1.0-9/p600x600/10407998_4626807244704_1055598540798912368_n.jpg?oh=1664643d6d9c98855a12aa45c037b2f6&oe=550D14A6, lets STOP due to:
#  HTTP Error 403: Forbidden
# Not able to SAVE image for species Nerodia rhombifer and url https://sphotos-a.xx.fbcdn.net/hphotos-ash4/260500_2035927453019_1803568_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Nerodia sipedon and url https://fbcdn-sphotos-a-a.akamaihd.net/hphotos-ak-ash4/s720x720/428387_722817042151_1727423185_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Agkistrodon contortrix and url https://sphotos-a.xx.fbcdn.net/hphotos-ash3/560674_4430081785381_809661731_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Heterodon platirhinos and url https://fbcdn-sphotos-h-a.akamaihd.net/hphotos-ak-prn1/s720x720/535694_648557718431_2117264236_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Micrurus tener and url https://sphotos-a.xx.fbcdn.net/hphotos-ash3/625577_10200399470884555_1185074297_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Agkistrodon piscivorus and url https://sphotos-a.xx.fbcdn.net/hphotos-frc1/72183_414598378638252_542042758_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Amplorhinus multimaculatus and url http://sphotos-a.xx.fbcdn.net/hphotos-prn1/63178_10151250882028168_340655061_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Thamnophis proximus and url https://sphotos-a.xx.fbcdn.net/hphotos-ash3/561196_414598615304895_554987777_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Thamnophis hammondii and url http://sphotos-a.xx.fbcdn.net/hphotos-ash4/320506_3803002644539_121106976_n.jpg, lets STOP due to:
#  HTTP Error 400: Bad Request
# Not able to SAVE image for species Bitis rubida and url https://static.inaturalist.org/photos/15741589/medium.gif?1524081290, lets STOP due to:
#  HTTP Error 403: Forbidden
# Total running time:  2.8429292400677997

# %% [markdown]
# # Check amount of inaturalist images we have

# %%
#choose appropriate genus for search
li_images_in = []
for species in glob.glob(os.path.join(path_data,'*')):
    li_images_in.extend([x for x in glob.glob(os.path.join(species,'*')) if x.endswith('.png')]) 
print('We have %d images collected from inaturalist'%len(li_images_in))
#we gain 5'000 with with languages: 108'712 to 114'584
# Out:
# We have 113892 images collected from inaturalist

# %% [markdown]
# # save metadata info (only collected images)

# %%
#in case, remove images in several species (should not happen in inaturalist)
li_test = []
for i in li_images_in:
    li_test.append(i.split('/')[-1].split('_')[-1].split('.')[0])
c = Counter(li_test)
c = {k:v for k,v in c.items() if v>1}
id_to_be_removed = list(set(c.keys()))
if len(id_to_be_removed)>0:
    print('ERROR: image sin different species!! probably 1 species-word was associated to several species over time')
    sys.exit()
#delete them after analysing why
#for i in li_images_in:
#    if i.split('/')[-1].split('_')[-1].split('.')[0] in id_to_be_removed:
#        #delete file
#        os.remove(i)
# Out:
# "for i in li_images_in:\n    if i.split('/')[-1].split('_')[-1].split('.')[0] in id_to_be_removed:\n        #delete file\n        os.remove(i)"

# %%
x1 = df.shape[0]
df = df[df['img_path'].isin(li_images_in)]
print('We lost %.2f percent of images (%d images) due to propably invalid url'%((x1-len(li_images_in))/x1*100, 
                                                                                x1-len(li_images_in)))
df.to_csv(os.path.join(path_data,'inaturalist_image_info.csv'), index=False, sep=';')
# Out:
# We lost 0.07 percent of images (75 images) due to propably invalid url

# %%
print(df.shape)
df.head(3)
# Out:
# (113892, 39)
#      id  observed_on_string observed_on    time_observed_at  \
# 1   369             5/26/07  2007-05-26                 NaT
# 5  1227  May 20, 2006 15:49  2006-05-20 2006-05-20 22:49:00
# 6  1228  May 13, 2006 19:36  2006-05-13 2006-05-14 02:36:00
#
#                     time_zone out_of_range  photographer    user_login  \
# 1  Eastern Time (US & Canada)          NaN            72  stellaoleary
# 5  Pacific Time (US & Canada)        False             1         kueda
# 6  Pacific Time (US & Canada)        False             1         kueda
#
#                   created_at                 updated_at  \
# 1  2008-06-05 14:04:53 -0500  2014-10-19 22:06:17 -0500
# 5  2009-01-13 02:29:54 -0600  2016-03-01 11:27:39 -0600
# 6  2009-01-13 02:29:54 -0600  2017-05-02 13:03:37 -0500
#
#                          ...                         positioning_device  \
# 1                        ...                                        NaN
# 5                        ...                                        NaN
# 6                        ...                                        NaN
#
#                                        species_guess  \
# 1                                    black rat snake
# 5  Western Terrestrial Garter Snake (Thamnophis e...
# 6                   Western Terrestrial Garter Snake
#
#                   species_word                       common_name  \
# 1  Pantherophis alleghaniensis                 Eastern Rat Snake
# 5           Thamnophis elegans  Western Terrestrial Garter Snake
# 6           Thamnophis elegans  Western Terrestrial Garter Snake
#
#   iconic_taxon_name taxon_id           datetaken                      species  \
# 1          Reptilia    59644 2007-05-26 00:00:00  Pantherophis alleghaniensis
# 5          Reptilia    28398 2006-05-20 22:49:00           Thamnophis elegans
# 6          Reptilia    28398 2006-05-14 02:36:00           Thamnophis elegans
#
#                                       saved_img_id  \
# 1  inaturalist_Pantherophis alleghaniensis_369.png
# 5          inaturalist_Thamnophis elegans_1227.png
# 6          inaturalist_Thamnophis elegans_1228.png
#
#                                             img_path
# 1  /home/camille/vm_exchange/Lab/snakes/datasets/...
# 5  /home/camille/vm_exchange/Lab/snakes/datasets/...
# 6  /home/camille/vm_exchange/Lab/snakes/datasets/...
#
# [3 rows x 39 columns]

# %%
li_test
# Out:
# ['10673210',
#  '1077169',
#  '10861777',
#  '1111226',
#  '13138004',
#  '13176756',
#  '13556005',
#  '13589641',
#  '14420377',
#  '14891940',
#  '15085550',
#  '16695788',
#  '16696826',
#  '16788246',
#  '16983693',
#  '17094215',
#  '17101063',
#  '17465323',
#  '17467494',
#  '2757765',
#  '3514069',
#  '3781909',
#  '3952185',
#  '4971689',
#  '6194545',
#  '7223641',
#  '9539421',
#  '12962117',
#  '15631414',
#  '52915',
#  '71076',
#  '16514067',
#  '16559647',
#  '2393053',
#  '2884364',
#  '29586',
#  '3534447',
#  '3534472',
#  '4278906',
#  '6913961',
#  '7718647',
#  '7718648',
#  '16237111',
#  '16384752',
#  '16384842',
#  '16385107',
#  '16385129',
#  '16526300',
#  '16622260',
#  '16622286',
#  '16622295',
#  '16622344',
#  '16622395',
#  '17066180',
#  '17066217',
