# %%
#basic package
import json
import tqdm
import os
import numpy
import glob
import pandas as pd
import sys
import shutil
import time
from PIL import Image
from collections import Counter
import pickle
from datetime import datetime

#url open to get image
import urllib.request
from urllib.request import urlopen

#get data in parallel
from multiprocessing import Pool

#plot (for image verification)
import matplotlib.cm as cm
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# Root directory of the project
ROOT_DIR = os.path.abspath("../")
path_data = os.path.join(ROOT_DIR,'datasets/herpmapper')

# %%
PACKAGE_PARENT = '../../..'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser('__file__'))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))

from UTILS.utils import get_image
# Out:
# /home/camille/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Note this notebook can not be run in the same time as get_flickr_data on my computer, but it could on the cluster.
#Hence, depending on your computer you might or not be able to run both in the same time, but if you try verify its 
#blocked

# %% [markdown]
# # Download data

# %% [markdown]
# ### list of species and its synonymes

# %%
#dowload dictionary with keys=species, value=list of its synonyms
dico_syn = pickle.load(open(os.path.join(ROOT_DIR,'datasets','synonyms','dico_species_lisyn.pkl'), 'rb'))

# %% [markdown]
# #### create list of species and their synonymes

# %%
li_species_word = []
for k,v in dico_syn.items():
    li_species_word.append(k)
    li_species_word.extend(v)
print('There is %d species-word in total to query for'%len(li_species_word))
# Out:
# There is 18289 species-word in total to query for

# %%
#dico with keys = species word and value its associated species name
dico_speciesword_species = {}
for k,v in dico_syn.items():
    for i in v+[k]:
            dico_speciesword_species[i] = k

# %% [markdown]
# ### herpmapper info

# %%
#to get url to ask in hermapper
df_all = pd.read_csv(os.path.join(path_data,'herpmapper.csv'))
print(df_all.shape)
df_all
# Out:
# (236944, 8)
#                ID        Date      Time  \
# 0            HM 1  2006-11-08  13:42:00
# 1            HM 2  2006-11-07  17:26:00
# 2            HM 3  2006-11-05  11:55:00
# 3            HM 4  2006-11-05  12:58:00
# 4            HM 5  2006-11-04  12:55:00
# 5            HM 6  2006-10-30  09:05:00
# 6            HM 7  2006-11-08  13:50:00
# 7            HM 8  2006-10-29  12:35:00
# 8            HM 9  2006-10-29  13:17:00
# 9           HM 10  2006-10-29  11:00:00
# 10          HM 11  2006-10-20  12:19:00
# 11          HM 12  2006-10-13  16:55:00
# 12          HM 13  2006-10-01  10:53:00
# 13          HM 14  2006-10-03  15:14:00
# 14          HM 15  2006-10-03  08:55:00
# 15          HM 16  2006-10-07  07:18:00
# 16          HM 17  2006-10-07  07:40:00
# 17          HM 18  2006-10-07  08:09:00
# 18          HM 19  2006-10-07  10:41:00
# 19          HM 20  2006-10-07  16:56:00
# 20          HM 21  2006-10-08  10:46:00
# 21          HM 22  2006-10-08  10:35:00
# 22          HM 23  2006-10-08  10:48:00
# 23          HM 24  2006-10-08  10:52:00
# 24          HM 25  2006-10-08  10:59:00
# 25          HM 26  2006-10-08  11:36:00
# 26          HM 27  2006-10-08  11:40:00
# 27          HM 28  2006-10-08  12:01:00
# 28          HM 29  2006-10-08  23:44:00
# 29          HM 30  2006-10-08  12:32:00
# ...           ...         ...       ...
# 236914  HM 240111  2018-09-07  20:09:51
# 236915  HM 240112  2018-09-08  20:38:10
# 236916  HM 240113  2018-09-08  21:39:12
# 236917  HM 240114  2018-08-26  08:13:57
# 236918  HM 240115  2018-08-26  08:38:17
# 236919  HM 240116  2018-08-26  15:15:46
# 236920  HM 240117  2018-06-01  22:42:46
# 236921  HM 240118  2018-10-08  09:24:31
# 236922  HM 240119  2018-10-08  10:28:02
# 236923  HM 240120  2018-10-08  10:42:10
# 236924  HM 240121  2018-10-08  11:07:33
# 236925  HM 240122  2018-10-08  11:11:17
# 236926  HM 240123  2018-10-08  12:13:47
# 236927  HM 240124  2018-10-08  13:01:32
# 236928  HM 240125  2018-10-08  13:49:50
# 236929  HM 240126  2018-10-08  13:09:19
# 236930  HM 240127  2018-10-09  08:28:06
# 236931  HM 240128  2018-10-07  18:42:18
# 236932  HM 240129  2018-10-08  19:02:06
# 236933  HM 240130  2018-10-08  19:04:25
# 236934  HM 240131  2018-10-08  19:05:09
# 236935  HM 240132  2018-10-08  15:36:44
# 236936  HM 240133  2018-10-05  20:49:48
# 236937  HM 240134  2018-10-05  21:10:10
# 236938  HM 240135  2018-10-06  21:28:07
# 236939  HM 240136  2018-10-07  11:09:10
# 236940  HM 240137  2018-10-07  16:22:00
# 236941  HM 240138  2018-10-04  23:05:54
# 236942  HM 240139  2018-10-04  16:12:40
# 236943  HM 240140  2018-09-14  15:25:34
#
#                                           Taxon                   Country  \
# 0                               Storeria dekayi  United States of America
# 1                            Lithobates pipiens  United States of America
# 2              Coluber constrictor flaviventris  United States of America
# 3                              Acris blanchardi  United States of America
# 4                               Storeria dekayi  United States of America
# 5                               Storeria dekayi  United States of America
# 6                  Thamnophis sirtalis sirtalis  United States of America
# 7                         Pantherophis vulpinus  United States of America
# 8                       Terrapene ornata ornata  United States of America
# 9                              Thamnophis radix  United States of America
# 10                        Pantherophis vulpinus  United States of America
# 11                           Lithobates pipiens  United States of America
# 12                        Pantherophis vulpinus  United States of America
# 13                          Pseudacris maculata  United States of America
# 14                              Storeria dekayi  United States of America
# 15                          Diadophis punctatus  United States of America
# 16                 Thamnophis sirtalis sirtalis  United States of America
# 17                    Nerodia sipedon pleuralis  United States of America
# 18                           Opheodrys aestivus  United States of America
# 19                       Pantherophis obsoletus  United States of America
# 20                  Terrapene carolina carolina  United States of America
# 21                          Plestiodon laticeps  United States of America
# 22                          Scincella lateralis  United States of America
# 23                          Lampropeltis getula  United States of America
# 24                         Sceloporus undulatus  United States of America
# 25           Aspidoscelis sexlineata sexlineata  United States of America
# 26                             Ambystoma opacum  United States of America
# 27      Notophthalmus viridescens louisianensis  United States of America
# 28                           Opheodrys aestivus  United States of America
# 29            Agkistrodon piscivorus leucostoma  United States of America
# ...                                         ...                       ...
# 236914             Thamnophis sirtalis sirtalis  United States of America
# 236915                   Agkistrodon contortrix  United States of America
# 236916                     Eurycea guttolineata  United States of America
# 236917                    Pantherophis guttatus  United States of America
# 236918            Sistrurus miliarius miliarius  United States of America
# 236919                     Ophisaurus ventralis  United States of America
# 236920                                Actinemys  United States of America
# 236921         Ophisaurus attenuatus attenuatus  United States of America
# 236922         Ophisaurus attenuatus attenuatus  United States of America
# 236923                  Lampropeltis triangulum  United States of America
# 236924                      Thamnophis proximus  United States of America
# 236925                      Thamnophis proximus  United States of America
# 236926                Coluber constrictor foxii  United States of America
# 236927                 Pituophis catenifer sayi  United States of America
# 236928                          Storeria dekayi  United States of America
# 236929                      Ambystoma mavortium  United States of America
# 236930                                      NaN                   Vietnam
# 236931           Agkistrodon contortrix mokasen  United States of America
# 236932                         Ambystoma opacum  United States of America
# 236933                         Ambystoma opacum  United States of America
# 236934                         Ambystoma opacum  United States of America
# 236935                       Plethodon cinereus                    Canada
# 236936                         Bufo gargarizans               South Korea
# 236937                     Dryophytes japonicus               South Korea
# 236938                         Hynobius leechii               South Korea
# 236939                             Rana coreana               South Korea
# 236940                    Xenochrophis piscator                 Sri Lanka
# 236941                          Rana huanrensis               South Korea
# 236942                   Scincella vandenburghi               South Korea
# 236943                      Chelydra serpentina  United States of America
#
#                   Level 1       Level 2  \
# 0                    Iowa       Johnson
# 1                    Iowa        Benton
# 2                    Iowa          Linn
# 3                    Iowa          Linn
# 4                    Iowa          Linn
# 5                    Iowa          Linn
# 6                    Iowa       Johnson
# 7                Illinois     Whiteside
# 8                Illinois       Carroll
# 9                Illinois         Henry
# 10                   Iowa          Linn
# 11                   Iowa          Linn
# 12                   Iowa          Linn
# 13                   Iowa          Linn
# 14                   Iowa          Linn
# 15               Illinois       Jackson
# 16               Illinois       Jackson
# 17               Illinois       Jackson
# 18               Illinois         Union
# 19               Illinois         Union
# 20               Illinois       Johnson
# 21               Illinois       Johnson
# 22               Illinois       Johnson
# 23               Illinois       Johnson
# 24               Illinois       Johnson
# 25               Illinois       Johnson
# 26               Illinois       Johnson
# 27               Illinois       Johnson
# 28               Illinois       Johnson
# 29               Illinois       Johnson
# ...                   ...           ...
# 236914     North Carolina  Transylvania
# 236915     North Carolina  Transylvania
# 236916     North Carolina  Transylvania
# 236917     North Carolina          Hyde
# 236918     North Carolina          Hyde
# 236919     North Carolina      Carteret
# 236920         California        Orange
# 236921           Illinois      Iroquois
# 236922           Illinois      Iroquois
# 236923           Illinois      Iroquois
# 236924            Indiana        Newton
# 236925            Indiana        Newton
# 236926           Illinois      Kankakee
# 236927           Illinois      Kankakee
# 236928            Indiana    Tippecanoe
# 236929       South Dakota         Sully
# 236930        Đông Nam Bộ    Bình Thuận
# 236931           Illinois         Union
# 236932           Illinois       Jackson
# 236933           Illinois       Jackson
# 236934           Illinois       Jackson
# 236935            Ontario       Toronto
# 236936        Gyeonggi-do      Gapyeong
# 236937        Gyeonggi-do      Gapyeong
# 236938              Seoul          Jung
# 236939        Gyeonggi-do        Goyang
# 236940              Kandy    Yatinuwara
# 236941  Chungcheongnam-do       Geumsan
# 236942  Chungcheongnam-do       Geumsan
# 236943            Vermont    Washington
#
#                                                  Vouchers
# 0       https://www.herpmapper.org/content/voucher/0/1...
# 1       https://www.herpmapper.org/content/voucher/0/2...
# 2       https://www.herpmapper.org/content/voucher/0/4...
# 3       https://www.herpmapper.org/content/voucher/0/1...
# 4       https://www.herpmapper.org/content/voucher/0/1...
# 5       https://www.herpmapper.org/content/voucher/0/1...
# 6       https://www.herpmapper.org/content/voucher/0/1...
# 7       https://www.herpmapper.org/content/voucher/0/1...
# 8       https://www.herpmapper.org/content/voucher/0/2...
# 9       https://www.herpmapper.org/content/voucher/0/2...
# 10      https://www.herpmapper.org/content/voucher/0/2...
# 11      https://www.herpmapper.org/content/voucher/0/2...
# 12      https://www.herpmapper.org/content/voucher/0/3...
# 13      https://www.herpmapper.org/content/voucher/0/3...
# 14      https://www.herpmapper.org/content/voucher/0/3...
# 15      https://www.herpmapper.org/content/voucher/0/3...
# 16      https://www.herpmapper.org/content/voucher/0/4...
# 17      https://www.herpmapper.org/content/voucher/0/4...
# 18      https://www.herpmapper.org/content/voucher/0/4...
# 19      https://www.herpmapper.org/content/voucher/0/4...
# 20      https://www.herpmapper.org/content/voucher/0/4...
# 21      https://www.herpmapper.org/content/voucher/0/4...
# 22      https://www.herpmapper.org/content/voucher/0/4...
# 23      https://www.herpmapper.org/content/voucher/0/4...
# 24      https://www.herpmapper.org/content/voucher/0/5...
# 25      https://www.herpmapper.org/content/voucher/0/5...
# 26      https://www.herpmapper.org/content/voucher/0/5...
# 27      https://www.herpmapper.org/content/voucher/0/5...
# 28      https://www.herpmapper.org/content/voucher/0/5...
# 29      https://www.herpmapper.org/content/voucher/0/5...
# ...                                                   ...
# 236914  https://www.herpmapper.org/content/voucher/33/...
# 236915  https://www.herpmapper.org/content/voucher/33/...
# 236916  https://www.herpmapper.org/content/voucher/33/...
# 236917  https://www.herpmapper.org/content/voucher/33/...
# 236918  https://www.herpmapper.org/content/voucher/33/...
# 236919  https://www.herpmapper.org/content/voucher/33/...
# 236920  https://www.herpmapper.org/content/voucher/33/...
# 236921  https://www.herpmapper.org/content/voucher/33/...
# 236922  https://www.herpmapper.org/content/voucher/33/...
# 236923  https://www.herpmapper.org/content/voucher/33/...
# 236924  https://www.herpmapper.org/content/voucher/33/...
# 236925  https://www.herpmapper.org/content/voucher/33/...
# 236926  https://www.herpmapper.org/content/voucher/33/...
# 236927  https://www.herpmapper.org/content/voucher/33/...
# 236928  https://www.herpmapper.org/content/voucher/33/...
# 236929  https://www.herpmapper.org/content/voucher/33/...
# 236930  https://www.herpmapper.org/content/voucher/33/...
# 236931  https://www.herpmapper.org/content/voucher/33/...
# 236932  https://www.herpmapper.org/content/voucher/33/...
# 236933  https://www.herpmapper.org/content/voucher/33/...
# 236934  https://www.herpmapper.org/content/voucher/33/...
# 236935  https://www.herpmapper.org/content/voucher/33/...
# 236936  https://www.herpmapper.org/content/voucher/33/...
# 236937  https://www.herpmapper.org/content/voucher/33/...
# 236938  https://www.herpmapper.org/content/voucher/33/...
# 236939  https://www.herpmapper.org/content/voucher/33/...
# 236940  https://www.herpmapper.org/content/voucher/33/...
# 236941  https://www.herpmapper.org/content/voucher/33/...
# 236942  https://www.herpmapper.org/content/voucher/33/...
# 236943  https://www.herpmapper.org/content/voucher/33/...
#
# [236944 rows x 8 columns]

# %% [markdown]
# #### preprocessing

# %%
#removing if not in our species-word list
df = df_all[df_all['Taxon'].isin(li_species_word)]
print(df.shape)
#removing if no url
df = df[~df['Vouchers'].isnull()]
print(df.shape)
#add associated species name of the species word
df.rename(columns={'Taxon':'species_word'},inplace=True)
df['species'] = df['species_word'].map(lambda x: dico_speciesword_species[x])
#creating alist of urls
df['url_list'] = df['Vouchers'].map(lambda x: x.split(','))
df.head(3)
# Out:
# (45643, 8)
# (45640, 8)
#      ID        Date      Time     species_word                   Country  \
# 0  HM 1  2006-11-08  13:42:00  Storeria dekayi  United States of America
# 4  HM 5  2006-11-04  12:55:00  Storeria dekayi  United States of America
# 5  HM 6  2006-10-30  09:05:00  Storeria dekayi  United States of America
#
#   Level 1  Level 2                                           Vouchers  \
# 0    Iowa  Johnson  https://www.herpmapper.org/content/voucher/0/1...
# 4    Iowa     Linn  https://www.herpmapper.org/content/voucher/0/1...
# 5    Iowa     Linn  https://www.herpmapper.org/content/voucher/0/1...
#
#            species                                           url_list
# 0  Storeria dekayi  [https://www.herpmapper.org/content/voucher/0/...
# 4  Storeria dekayi  [https://www.herpmapper.org/content/voucher/0/...
# 5  Storeria dekayi  [https://www.herpmapper.org/content/voucher/0/...

# %%
li_species_herpmapper = list(set(df['species'].tolist()))
print('There is %d species with at least one image in HerpMapper'%len(li_species_herpmapper))
# Out:
# There is 998 species with at least one image in HerpMapper

# %%
#create a df with one line per image instead
df = df.set_index(['Date', 'Level 1', 'Level 2', 'Time', 'Country', 'species_word','ID',
                   'species'])['url_list'].apply(pd.Series).stack()
df = df.reset_index()
df = df.rename(columns={0:'url'})
#create a single id per image based on the info of herpmapper that is not supposed to changed
#TODO: be verified by Andrew if this id is indeed unique (herpmapper should know)
df['id'] = df['url'].map(lambda x: '-'.join(x.split('.')[-2].split('/')[-2:]))
df['saved_img_id'] = df.apply(lambda x: 'herpmapper_'+x['species']+'_'+x['id']+".png",axis=1)
df['img_path'] = df.apply(lambda x: os.path.join(path_data,x['species'], x['saved_img_id']), axis=1)
print('There is %d images to download from Herpmapper'%df.shape[0])
#we gain 558 images using all synonymes ending up to 53389 images. then we ended up to 59478 using all language
df.head(3)
# Out:
# There is 59478 images to download from Herpmapper
#          Date Level 1  Level 2      Time                   Country  \
# 0  2006-11-08    Iowa  Johnson  13:42:00  United States of America
# 1  2006-11-04    Iowa     Linn  12:55:00  United States of America
# 2  2006-11-04    Iowa     Linn  12:55:00  United States of America
#
#       species_word    ID          species  level_8  \
# 0  Storeria dekayi  HM 1  Storeria dekayi        0
# 1  Storeria dekayi  HM 5  Storeria dekayi        0
# 2  Storeria dekayi  HM 5  Storeria dekayi        1
#
#                                                  url    id  \
# 0  https://www.herpmapper.org/content/voucher/0/1...   0-1
# 1  https://www.herpmapper.org/content/voucher/0/1...  0-13
# 2   https://www.herpmapper.org/content/voucher/0/...  0-14
#
#                           saved_img_id  \
# 0   herpmapper_Storeria dekayi_0-1.png
# 1  herpmapper_Storeria dekayi_0-13.png
# 2  herpmapper_Storeria dekayi_0-14.png
#
#                                             img_path
# 0  /home/camille/vm_exchange/Lab/snakes/datasets/...
# 1  /home/camille/vm_exchange/Lab/snakes/datasets/...
# 2  /home/camille/vm_exchange/Lab/snakes/datasets/...

# %%
#make a good date puting to 1000-01-01 all wrong dates
df['Date'] = df['Date'].map(lambda x: '1000-01-01' if x.split('-')[-1]=='00' else x)
df['Date'] = df['Date'].map(lambda x: '1000-01-01' if x.split('-')[1]=='00' else x)
df['Date'] = df['Date'].map(lambda x: '1000-01-01' if x.split('-')[0]=='0000' else x)
df['Time'] = df['Time'].fillna('00:00:00')
df['datetaken'] = df.apply(lambda x: datetime(datetime.strptime(x['Date'], "%Y-%m-%d").year, 
                                              datetime.strptime(x['Date'], "%Y-%m-%d").month, 
                                              datetime.strptime(x['Date'], "%Y-%m-%d").day, 
                                              int(x['Time'].split(':')[0]), 
                                              int(x['Time'].split(':')[1]),
                                              int(x['Time'].split(':')[2])), axis=1)
#small verification
#df[['observed_on','time_observed_at','observed_on_string','datetaken']]

# %%
if len(df['id'].tolist())!=len(set(df['id'].tolist())):
    print('ERROR: not unique ids of herpmapper images')
    sys.exit()

# %% [markdown]
# # Download Herpmapper images

# %% [markdown]
# #in case to erase all (not herpmapper.csv data given by Andrew)
# for species in glob.glob(os.path.join(path_data,'*')):
#     if not species.endswith('.csv'):
#         shutil.rmtree(species)

# %%
#create appropriate folders if not existing
for species in li_species_herpmapper:
    folder_path_s = os.path.join(path_data,species)
    if not os.path.exists(folder_path_s):
        os.makedirs(folder_path_s)

# %%
def download_image(i):
    #download image and save it
    species = df.iloc[i]['species']
    f = os.path.join(path_data, species,'herpmapper_'+species+'_'+df.iloc[i]['id']+".png")
    get_image(url=df.iloc[i]['url'], path=f, name=df.iloc[i]['species_word'])

# %%
#compute time needed to gather all images
start = time.time()
with Pool(3) as p:
    p.map(download_image, range(df.shape[0]))
end = time.time()
print ("Total running time: ", (end-start)/60) #in minutes
# Out:
# Not able to SAVE image for species Crotalus atrox and url  https://www.herpmapper.org/content/voucher/6/60465.mp3, lets STOP due to:
#  cannot identify image file <_io.BytesIO object at 0x7fbc973fd1a8>
# 200
# Not able to SAVE image for species Opheodrys vernalis and url https://www.herpmapper.org/content/voucher/6/63743.jpg, lets STOP due to:
#  HTTP Error 404: Not Found
# Not able to SAVE image for species Pantherophis vulpinus and url https://www.herpmapper.org/content/voucher/26/260082.jpg, lets STOP due to:
#  HTTP Error 404: Not Found
# Total running time:  2.643633194764455

# %% [markdown]
# # Verify error in download

# %% [markdown]
# #indeed url can not be found
# url = df[(df['species']=='Opheodrys vernalis')&(df['id']=='6-63743')]['url'].values[0]
# print(url)
# img = Image.open(urlopen(url))
# plt.imshow(img);

# %% [markdown]
# #indeed: its a video
# url = df[(df['species']=='Crotalus atrox')&(df['id']=='6-60465')]['url'].values[0]
# print(url)
# img = Image.open(urlopen(url))
# plt.imshow(img);

# %% [markdown]
# #indeed url can not be found
# url = df[(df['species']=='Pantherophis vulpinus')&(df['id']=='26-260082')]['url'].values[0]
# print(url)
# img = Image.open(urlopen(url))
# plt.imshow(img);

# %% [markdown]
# # Check amount of Herpmapper images we have

# %%
#choose appropriate genus for search
li_images_hm = []
for species in glob.glob(os.path.join(path_data,'*')):
    li_images_hm.extend([x for x in glob.glob(os.path.join(species,'*')) if x.endswith('.png')]) 
print('We have %d images collected from Herpmapper'%len(li_images_hm))
# Out:
# We have 59475 images collected from Herpmapper

# %% [markdown]
# # save metadata info (only collected images)

# %%
#in case, remove images in several species (should not happen in inaturalist)
li_test = []
for i in li_images_hm:
    li_test.append(i.split('/')[-1].split('_')[-1].split('.')[0])
c = Counter(li_test)
c = {k:v for k,v in c.items() if v>1}
id_to_be_removed = list(set(c.keys()))
if len(id_to_be_removed)>0:
    print('ERROR: image sin different species!! probably 1 species-word was associated to several species over time')
    sys.exit()
#delete them after analysing why
#for i in li_images_hm:
#    if i.split('/')[-1].split('_')[-1].split('.')[0] in id_to_be_removed:
#        #delete file
#        os.remove(i)

# %%
x1 = df.shape[0]
df = df[df['img_path'].isin(li_images_hm)]
print('We lost %.2f percent of images (%d images)'%((x1-len(li_images_hm))/x1*100,x1-len(li_images_hm)))
df.to_csv(os.path.join(path_data,'herpmapper_image_info.csv'), index=False, sep=';')
print(df.shape)
df.head(3)
# Out:
# We lost 0.01 percent of images (3 images)
# (59475, 14)
#          Date Level 1  Level 2      Time                   Country  \
# 0  2006-11-08    Iowa  Johnson  13:42:00  United States of America
# 1  2006-11-04    Iowa     Linn  12:55:00  United States of America
# 2  2006-11-04    Iowa     Linn  12:55:00  United States of America
#
#       species_word    ID          species  level_8  \
# 0  Storeria dekayi  HM 1  Storeria dekayi        0
# 1  Storeria dekayi  HM 5  Storeria dekayi        0
# 2  Storeria dekayi  HM 5  Storeria dekayi        1
#
#                                                  url    id  \
# 0  https://www.herpmapper.org/content/voucher/0/1...   0-1
# 1  https://www.herpmapper.org/content/voucher/0/1...  0-13
# 2   https://www.herpmapper.org/content/voucher/0/...  0-14
#
#                           saved_img_id  \
# 0   herpmapper_Storeria dekayi_0-1.png
# 1  herpmapper_Storeria dekayi_0-13.png
# 2  herpmapper_Storeria dekayi_0-14.png
#
#                                             img_path            datetaken
# 0  /home/camille/vm_exchange/Lab/snakes/datasets/...  2006-11-08 13:42:00
# 1  /home/camille/vm_exchange/Lab/snakes/datasets/...  2006-11-04 12:55:00
# 2  /home/camille/vm_exchange/Lab/snakes/datasets/...  2006-11-04 12:55:00
